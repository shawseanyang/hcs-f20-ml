# %%
# import required libraries
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import math

from PIL import Image

# %%
# convert source images into numpy arrays
cap = 100

circle_images = []
i = 0
for file in glob.glob('./circle/*.png'):   
    if i >= cap:
        break
    i = i + 1
    image = np.array(Image.open(file).convert('L'))
    flattened = []
    for row in image:
        flattened.extend(row)
    inverted = [];
    for item in flattened:
        inverted.append(-1 * item + 255)
    circle_images.append(inverted)
circle_data = np.array(circle_images);

square_images = []
i = 0
for file in glob.glob('./square/*.png'):   
    if i >= cap:
        break
    i = i + 1
    image = np.array(Image.open(file).convert('L'))
    flattened = []
    for row in image:
        flattened.extend(row)
    inverted = [];
    for item in flattened:
        inverted.append(-1 * item + 255)
    square_images.append(inverted)
square_data = np.array(square_images);

triangle_images = []
i = 0
for file in glob.glob('./triangle/*.png'):   
    if i >= cap:
        break
    i = i + 1
    image = np.array(Image.open(file).convert('L'))
    flattened = []
    for row in image:
        flattened.extend(row)
    inverted = [];
    for item in flattened:
        inverted.append(-1 * item + 255)
    triangle_images.append(inverted)
triangle_data = np.array(triangle_images);

# %%
# randomizing the data
np.random.shuffle(circle_data)
np.random.shuffle(square_data)
np.random.shuffle(triangle_data)

# splitting into test and train
train_percent = 0.8

circle_cutoff = math.floor(len(circle_data) * train_percent)
circle_trainX = circle_data[:circle_cutoff]
circle_trainY = np.tile([1,0,0], (len(circle_trainX),1))
circle_testX = circle_data[circle_cutoff:]
circle_testY = np.tile([1,0,0], (len(circle_testX),1))

square_cutoff = math.floor(len(square_data) * train_percent)
square_trainX = square_data[:square_cutoff]
square_trainY = np.tile([0,1,0], (len(square_trainX),1))
square_testX = square_data[square_cutoff:]
square_testY = np.tile([0,1,0], (len(square_testX),1))

triangle_cutoff = math.floor(len(triangle_data) * train_percent)
triangle_trainX = triangle_data[:triangle_cutoff]
triangle_trainY = np.tile([0,0,1], (len(triangle_trainX),1))
triangle_testX = triangle_data[triangle_cutoff:]
triangle_testY = np.tile([0,0,1], (len(triangle_testX),1))

# building the training and testing arrays
X_train = np.concatenate((circle_trainX, square_trainX, triangle_trainX))
Y_train = np.concatenate((circle_trainY, square_trainY, triangle_trainY))
X_test = np.concatenate((circle_testX, square_testX, triangle_testX))
Y_test = np.concatenate((circle_testY, square_testY, triangle_testY))

# %%
# normalize the X data
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255

# %%
# building out the model
model = keras.models.Sequential()

# adding the first hidden layer
model.add(layers.Dense(512, input_shape=(40000,)))
model.add(layers.Activation('relu'))                            
model.add(layers.Dropout(0.2))

# adding the second hidden layer
model.add(layers.Dense(512))
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.2))

# adding the output layer
model.add(layers.Dense(3))
model.add(layers.Activation('softmax'))

# %%
# compiling the model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
# training the model
history = model.fit(X_train, Y_train,
          batch_size=128, epochs=50,
          verbose=2,
          validation_data=(X_test, Y_test))
# Out:
# Epoch 1/50
# 2/2 - 0s - loss: 5.4648 - accuracy: 0.3750 - val_loss: 14.2752 - val_accuracy: 0.5000
# Epoch 2/50
# 2/2 - 0s - loss: 18.3526 - accuracy: 0.4208 - val_loss: 12.2612 - val_accuracy: 0.3333
# Epoch 3/50
# 2/2 - 0s - loss: 7.5205 - accuracy: 0.5042 - val_loss: 6.3243 - val_accuracy: 0.6667
# Epoch 4/50
# 2/2 - 0s - loss: 5.9286 - accuracy: 0.5750 - val_loss: 3.5564 - val_accuracy: 0.5833
# Epoch 5/50
# 2/2 - 0s - loss: 2.8163 - accuracy: 0.6542 - val_loss: 1.5446 - val_accuracy: 0.6167
# Epoch 6/50
# 2/2 - 0s - loss: 1.8338 - accuracy: 0.6542 - val_loss: 1.4612 - val_accuracy: 0.5667
# Epoch 7/50
# 2/2 - 0s - loss: 1.8835 - accuracy: 0.6000 - val_loss: 1.2314 - val_accuracy: 0.7167
# Epoch 8/50
# 2/2 - 0s - loss: 1.2593 - accuracy: 0.7083 - val_loss: 0.5311 - val_accuracy: 0.8500
# Epoch 9/50
# 2/2 - 0s - loss: 0.8992 - accuracy: 0.7458 - val_loss: 0.5847 - val_accuracy: 0.7667
# Epoch 10/50
# 2/2 - 0s - loss: 1.1266 - accuracy: 0.7750 - val_loss: 0.4214 - val_accuracy: 0.8667
# Epoch 11/50
# 2/2 - 0s - loss: 0.4345 - accuracy: 0.8500 - val_loss: 0.4947 - val_accuracy: 0.8833
# Epoch 12/50
# 2/2 - 0s - loss: 0.3570 - accuracy: 0.8875 - val_loss: 0.4314 - val_accuracy: 0.8167
# Epoch 13/50
# 2/2 - 0s - loss: 0.4334 - accuracy: 0.8708 - val_loss: 0.4206 - val_accuracy: 0.8000
# Epoch 14/50
# 2/2 - 0s - loss: 0.4623 - accuracy: 0.8500 - val_loss: 0.2884 - val_accuracy: 0.8500
# Epoch 15/50
# 2/2 - 0s - loss: 0.3414 - accuracy: 0.8917 - val_loss: 0.2761 - val_accuracy: 0.9167
# Epoch 16/50
# 2/2 - 0s - loss: 0.2593 - accuracy: 0.9125 - val_loss: 0.3728 - val_accuracy: 0.9000
# Epoch 17/50
# 2/2 - 0s - loss: 0.3192 - accuracy: 0.9000 - val_loss: 0.2036 - val_accuracy: 0.9167
# Epoch 18/50
# 2/2 - 0s - loss: 0.1843 - accuracy: 0.9417 - val_loss: 0.1651 - val_accuracy: 0.9333
# Epoch 19/50
# 2/2 - 0s - loss: 0.2931 - accuracy: 0.8750 - val_loss: 0.1405 - val_accuracy: 0.9333
# Epoch 20/50
# 2/2 - 0s - loss: 0.1628 - accuracy: 0.9375 - val_loss: 0.1787 - val_accuracy: 0.9167
# Epoch 21/50
# 2/2 - 0s - loss: 0.1354 - accuracy: 0.9500 - val_loss: 0.1991 - val_accuracy: 0.9167
# Epoch 22/50
# 2/2 - 0s - loss: 0.1263 - accuracy: 0.9625 - val_loss: 0.1099 - val_accuracy: 0.9500
# Epoch 23/50
# 2/2 - 0s - loss: 0.1149 - accuracy: 0.9583 - val_loss: 0.0934 - val_accuracy: 0.9500
# Epoch 24/50
# 2/2 - 0s - loss: 0.1334 - accuracy: 0.9417 - val_loss: 0.0922 - val_accuracy: 0.9500
# Epoch 25/50
# 2/2 - 0s - loss: 0.1027 - accuracy: 0.9500 - val_loss: 0.0672 - val_accuracy: 0.9667
# Epoch 26/50
# 2/2 - 0s - loss: 0.0588 - accuracy: 0.9792 - val_loss: 0.0711 - val_accuracy: 0.9667
# Epoch 27/50
# 2/2 - 0s - loss: 0.0447 - accuracy: 0.9833 - val_loss: 0.0694 - val_accuracy: 0.9667
# Epoch 28/50
# 2/2 - 0s - loss: 0.0651 - accuracy: 0.9750 - val_loss: 0.0468 - val_accuracy: 0.9833
# Epoch 29/50
# 2/2 - 0s - loss: 0.0289 - accuracy: 0.9917 - val_loss: 0.0416 - val_accuracy: 0.9833
# Epoch 30/50
# 2/2 - 0s - loss: 0.0470 - accuracy: 0.9833 - val_loss: 0.0408 - val_accuracy: 0.9833
# Epoch 31/50
# 2/2 - 0s - loss: 0.0328 - accuracy: 0.9833 - val_loss: 0.0426 - val_accuracy: 0.9833
# Epoch 32/50
# 2/2 - 0s - loss: 0.0486 - accuracy: 0.9958 - val_loss: 0.0457 - val_accuracy: 0.9833
# Epoch 33/50
# 2/2 - 0s - loss: 0.0226 - accuracy: 0.9958 - val_loss: 0.0486 - val_accuracy: 0.9833
# Epoch 34/50
# 2/2 - 0s - loss: 0.0289 - accuracy: 0.9917 - val_loss: 0.0451 - val_accuracy: 0.9833
# Epoch 35/50
# 2/2 - 0s - loss: 0.0164 - accuracy: 0.9958 - val_loss: 0.0389 - val_accuracy: 0.9833
# Epoch 36/50
# 2/2 - 0s - loss: 0.0205 - accuracy: 0.9958 - val_loss: 0.0330 - val_accuracy: 0.9833
# Epoch 37/50
# 2/2 - 0s - loss: 0.0113 - accuracy: 1.0000 - val_loss: 0.0292 - val_accuracy: 0.9833
# Epoch 38/50
# 2/2 - 0s - loss: 0.0212 - accuracy: 0.9875 - val_loss: 0.0283 - val_accuracy: 0.9833
# Epoch 39/50
# 2/2 - 0s - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.0303 - val_accuracy: 0.9833
# Epoch 40/50
# 2/2 - 0s - loss: 0.0086 - accuracy: 0.9958 - val_loss: 0.0331 - val_accuracy: 0.9833
# Epoch 41/50
# 2/2 - 0s - loss: 0.0122 - accuracy: 0.9958 - val_loss: 0.0311 - val_accuracy: 0.9833
# Epoch 42/50
# 2/2 - 0s - loss: 0.0090 - accuracy: 0.9958 - val_loss: 0.0271 - val_accuracy: 0.9833
# Epoch 43/50
# 2/2 - 0s - loss: 0.0100 - accuracy: 0.9958 - val_loss: 0.0215 - val_accuracy: 0.9833
# Epoch 44/50
# 2/2 - 0s - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.0191 - val_accuracy: 0.9833
# Epoch 45/50
# 2/2 - 0s - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.0181 - val_accuracy: 1.0000
# Epoch 46/50
# 2/2 - 0s - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.0180 - val_accuracy: 1.0000
# Epoch 47/50
# 2/2 - 0s - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.0182 - val_accuracy: 1.0000
# Epoch 48/50
# 2/2 - 0s - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.0182 - val_accuracy: 1.0000
# Epoch 49/50
# 2/2 - 0s - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.0196 - val_accuracy: 0.9833
# Epoch 50/50
# 2/2 - 0s - loss: 0.0102 - accuracy: 0.9958 - val_loss: 0.0256 - val_accuracy: 0.9833
