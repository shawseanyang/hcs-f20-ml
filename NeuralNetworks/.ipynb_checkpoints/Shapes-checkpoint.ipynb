# %%
# import required libraries
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import math

from PIL import Image

# %%
# convert source images into numpy arrays
cap = 100

circle_images = []
i = 0
for file in glob.glob('./circle/*.png'):   
    if i >= cap:
        break
    i = i + 1
    image = np.array(Image.open(file).convert('L'))
    flattened = []
    for row in image:
        flattened.extend(row)
    inverted = [];
    for item in flattened:
        inverted.append(-1 * item + 255)
    circle_images.append(inverted)
circle_data = np.array(circle_images);

print('done')

square_images = []
i = 0
for file in glob.glob('./square/*.png'):   
    if i >= cap:
        break
    i = i + 1
    image = np.array(Image.open(file).convert('L'))
    flattened = []
    for row in image:
        flattened.extend(row)
    inverted = [];
    for item in flattened:
        inverted.append(-1 * item + 255)
    square_images.append(inverted)
square_data = np.array(square_images);

print('done')

triangle_images = []
i = 0
for file in glob.glob('./triangle/*.png'):   
    if i >= cap:
        break
    i = i + 1
    image = np.array(Image.open(file).convert('L'))
    flattened = []
    for row in image:
        flattened.extend(row)
    inverted = [];
    for item in flattened:
        inverted.append(-1 * item + 255)
    triangle_images.append(inverted)
triangle_data = np.array(triangle_images);

print('done')
# Out:
# done
# done
# done

# %%
# randomizing the data
np.random.shuffle(circle_data)
np.random.shuffle(square_data)
np.random.shuffle(triangle_data)

# splitting into test and train
train_percent = 0.8

circle_cutoff = math.floor(len(circle_data) * train_percent)
circle_trainX = circle_data[:circle_cutoff]
circle_trainY = np.tile([1,0,0], (len(circle_trainX),1))
circle_testX = circle_data[circle_cutoff:]
circle_testY = np.tile([1,0,0], (len(circle_testX),1))

square_cutoff = math.floor(len(square_data) * train_percent)
square_trainX = square_data[:square_cutoff]
square_trainY = np.tile([0,1,0], (len(square_trainX),1))
square_testX = square_data[square_cutoff:]
square_testY = np.tile([0,1,0], (len(square_testX),1))

triangle_cutoff = math.floor(len(triangle_data) * train_percent)
triangle_trainX = triangle_data[:triangle_cutoff]
triangle_trainY = np.tile([0,0,1], (len(triangle_trainX),1))
triangle_testX = triangle_data[triangle_cutoff:]
triangle_testY = np.tile([0,0,1], (len(triangle_testX),1))

# building the training and testing arrays
X_train = np.concatenate((circle_trainX, square_trainX, triangle_trainX))
Y_train = np.concatenate((circle_trainY, square_trainY, triangle_trainY))
X_test = np.concatenate((circle_testX, square_testX, triangle_testX))
Y_test = np.concatenate((circle_testY, square_testY, triangle_testY))

# %%
# normalize the X data
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255

# %%
# building out the model
model = keras.models.Sequential()

# adding the first hidden layer
model.add(layers.Dense(512, input_shape=(40000,)))
model.add(layers.Activation('relu'))                            
model.add(layers.Dropout(0.2))

# adding the second hidden layer
model.add(layers.Dense(512))
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.2))

# adding the output layer
model.add(layers.Dense(3))
model.add(layers.Activation('softmax'))

# %%
# compiling the model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
# training the model
history = model.fit(X_train, Y_train,
          batch_size=128, epochs=50,
          verbose=2,
          validation_data=(X_test, Y_test))
# Out:
# Epoch 1/50
# 2/2 - 0s - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.0071 - val_accuracy: 1.0000
# Epoch 2/50
# 2/2 - 0s - loss: 0.0068 - accuracy: 0.9958 - val_loss: 0.0043 - val_accuracy: 1.0000
# Epoch 3/50
# 2/2 - 0s - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 4/50
# 2/2 - 0s - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 5/50
# 2/2 - 0s - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 6/50
# 2/2 - 0s - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 7/50
# 2/2 - 0s - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0036 - val_accuracy: 1.0000
# Epoch 8/50
# 2/2 - 0s - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 9/50
# 2/2 - 0s - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0063 - val_accuracy: 1.0000
# Epoch 10/50
# 2/2 - 0s - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 1.0000
# Epoch 11/50
# 2/2 - 0s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 1.0000
# Epoch 12/50
# 2/2 - 0s - loss: 0.0097 - accuracy: 0.9958 - val_loss: 0.0055 - val_accuracy: 1.0000
# Epoch 13/50
# 2/2 - 0s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 14/50
# 2/2 - 0s - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 15/50
# 2/2 - 0s - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 16/50
# 2/2 - 0s - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 17/50
# 2/2 - 0s - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 18/50
# 2/2 - 0s - loss: 7.9410e-04 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 19/50
# 2/2 - 0s - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 20/50
# 2/2 - 0s - loss: 7.0619e-04 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 21/50
# 2/2 - 0s - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 22/50
# 2/2 - 0s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 23/50
# 2/2 - 0s - loss: 6.7951e-04 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 24/50
# 2/2 - 0s - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 25/50
# 2/2 - 0s - loss: 9.8420e-04 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 26/50
# 2/2 - 0s - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 27/50
# 2/2 - 0s - loss: 8.9332e-04 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 28/50
# 2/2 - 0s - loss: 9.1605e-04 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 29/50
# 2/2 - 0s - loss: 7.3266e-04 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 30/50
# 2/2 - 0s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 31/50
# 2/2 - 0s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 32/50
# 2/2 - 0s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 33/50
# 2/2 - 0s - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 34/50
# 2/2 - 0s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 35/50
# 2/2 - 0s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 36/50
# 2/2 - 0s - loss: 0.0041 - accuracy: 0.9958 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 37/50
# 2/2 - 0s - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 38/50
# 2/2 - 0s - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 39/50
# 2/2 - 0s - loss: 8.4363e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 40/50
# 2/2 - 0s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 41/50
# 2/2 - 0s - loss: 6.8194e-04 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 42/50
# 2/2 - 0s - loss: 6.6666e-04 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 43/50
# 2/2 - 0s - loss: 5.6471e-04 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 44/50
# 2/2 - 0s - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 45/50
# 2/2 - 0s - loss: 2.8770e-04 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 46/50
# 2/2 - 0s - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 47/50
# 2/2 - 0s - loss: 4.6272e-04 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 48/50
# 2/2 - 0s - loss: 4.2170e-04 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 49/50
# 2/2 - 0s - loss: 8.9743e-04 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 50/50
# 2/2 - 0s - loss: 6.6792e-04 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000
